# %% [markdown]
# ## <center>Лабораторная работа №12</center>
#
# **Тема:** Разработка, отладка и испытание программ создания классов и экземпляров классов
#
# **Цель:** Получить навыки разработки, отладки и испытаний программ, использующих конструкторы для создания экземпляров классов.
#
# **Материал:** [Лекция 3.1 Определение классов и создание экземпляра класса](../../material/lectures/lect03_01.ipynb)

# %% [markdown]
# ## <center>Индивидуальные задания</center>
# ### <font color=blue>Задание 1.</font>
#
# 1) Описать класс с именем STUDENT, содержащий следующие поля:
# - фамилия и инициалы;
# - номер группы;
# - успеваемость (массив из пяти элементов).
#
# 2) Написать программу, выполняющую следующие действия
# - ввод с клавиатуры данных в массив, состоящий из десяти структур типа STUDENT;
# - вывод на дисплей фамилий и номеров групп для всех студентов, имеющих хотя бы одну неудовлетворительную отметку;
# - если таких студентов нет, вывести соответствующее сообщение.

# %% [markdown]
# ### <font color=blue>Задание 2.</font>
#
# Исходными данными для выполнения лабораторной работы является программа, разработанная в [лабораторной работе №11](../../material/lectures/lab_11_NN.ipynb).
#
# 1. Добавить в класс конструктор, выполняющий инициализацию всех или некоторых атрибутов экземпляра класса. Те атрибуты, которые инициализируются в конструкторе, удалить из описания класса.
# 2. Сделать так, чтобы инициализация атрибутов в конструкторе выполнялась с помощью сеттеров.
# 3. Создать одномерный список из 10 объектов класса (данные ввести с клавиатуры) используя конструктор.
# 5. Добавить в класс деструктор (финализатор). В теле деструктора реализовать вывод сообщения о том, что деструктор выполнился. Убедиться, что при завершении программы деструктор вызывается для каждого элемента списка.
#
# Предметные области по вариантам (из [лабораторной работы №11](../../material/lectures/lab_11_NN.ipynb)):
# 1. Сведения об автомобилях.
# 2. Сведения о странах.
# 3. Сведения о жилых домах микрорайона.
# 4. Сведения о гражданах.
# 5. Сведения о морских судах.
# 6. Сведения о гражданских воздушных судах (пассажирских самолетах).
# 7. Сведения о военных воздушных судах.
# 8. Сведения о водных ресурсах.
# 9. Сведения о компьютерах.
# 10. Сведения о принтерах.
# 11. Сведения о сканерах.
# 12. Сведения о космических полетах.
# 13. Сведения о книгах.
# 14. Сведения о музыкальной коллекции.
# 15. Сведения о химическом элементе.
