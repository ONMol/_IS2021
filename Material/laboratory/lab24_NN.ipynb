# %% [markdown]
# ## <center>Лабораторная работа №24</center>
#
# **Тема:** Разработка, отладка и испытание программ управления массивами с помощью универсальных функций
#
# **Цель:** Получить навыки разработки, отладки и испытаний программ, использующих универсальные функции.
#
# **Материал:** [Лекция 6.1  Библиотека NumPy. Массивы библиотеки NumPy](../../material/lectures/lect06_01.ipynb)

# %% [markdown]
# ### Индивидуальные задания

# %% [markdown]
# ### Выполните задания вашего варианта лабораторной работы №23, используя универсальную функцию
#
# #### <center>Лабораторная работа №23</center>
# Создайте прямоугоьный массив numpy со случайным количеством столбцов и строк от 15 до 100. Заполните его целыми числами от 1 до 1000. Выведите его на экран полностью.
#
# **Выполните индивидуальное задание**
#
# **Варианты 1,6,11**
# Найдите минимальный элемент в строке вашего варианта. Выведите его на экран. Найдите произведение матрицы на этот элемент.
#
# **Варианты 2,7,12**
# Найдите максимальный элемент в столбце вашего варианта. Выведите его на экран. Найдите сумму элементов матрицы и найденного элемента.
#
# **Варианты 3,8,13**
# Найдите минимальный элемент в столбце вашего варианта. Выведите его на экран. Найдите сумму элементов матрицы и найденного элемента.
#
# **Варианты 4,9,14**
# Найдите максимальный элемент с строке вашего варианта. Выведите его на экран. Найдите произведение матрицы на этот элемент.
#
# **Варианты 5,10,15**
# Найдите разность значений максимального и минимального элемента всей матрицы. Выведите ее на экран. Найдите прозведение элементов матрицы и найденоого значения.
#
# Выведите на экран обновленный массив.
