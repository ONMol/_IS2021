# %% [markdown]
# ## <center>Лабораторная работа №16</center>
#
# **Тема:** Разработка, отладка и испытание программ с применением декораторов свойств классов
#
# **Цель:** Получить навыки разработки, отладки и испытаний программ, использующих декоратор свойств классов.
#
# **Материал:** [Лекция 3.4  Свойства и декораторы классов](../../material/lectures/lect03_04.ipynb)

# %% [markdown]
# **Пример** использования декоратора @property смотрите в материале лекции.

# %% [markdown]
# **<center>Индивидуальные задания:</center>**
#
# **Описать класс, содержащий информацию об одном из понятий реального мира (не менее 4 свойств) согласно индивидуального задания и примените к нему декоратор @property. Изменение значения свойств осуществите с помощью сетеров этих свойств** См.
# [**Лекция 3_1. Определение классов и создание экземпляра класса**](material/lectures/lect03_01.ipynb)
#
# Продемонстрируйте работу декоратора через задание свойств объекта класса конструктором, сеттером и непосредстсвенным изменением значения (должно вызвать ошибку).

# %% [markdown]
# **Вариант 1** Спортивная команда.
#
# **Вариант 2** Покупка в магазине
#
# **Вариант 3** Сортировка списка методом обмена по возрастанию.
#
# **Вариант 4** Учебная аудитория.
#
# **Вариант 5** Абитуриент.
#
# **Вариант 6** Товар.
#
# **Вариант 7** Город.
#
# **Вариант 8** Домашнее животное.
#
# **Вариант 9** Фильм.
#
# **Вариант 10** Сотрудник фирмы.
#
# **Вариант 11** Дом.
#
# **Вариант 12** Автомобиль.
#
# **Вариант 13** Страна.
#
# **Вариант 14** Компьютер.
#
# **Вариант 15** Пациент.
