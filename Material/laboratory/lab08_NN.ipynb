# %% [markdown]
# ## <center>Лабораторная работа №8</center>
#
# **Тема:** Разработка, отладка и испытание алгоритмов и программ с использованием множеств.
#
# **Цель:** Получить навыки разработки, отладки и испытаний программ, использующих переменные множественного типа и выполнении простейших операций над ними.
#
# **Материал:** [Лекция 2.2 Множества](../../material/lectures/lect02_02.ipynb)
#
# #### <center>Теоретический материал</center>

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # <center>Порядок выполнения работы</center>
# #### Задание 1.
# **Даны два множества чисел.**
#
#     1) Найдите все различные числа в этих множествах.

# %% [markdown]
#     2) Найдите все числа, которые входят как в первое, так и во второе множества и выведите их в порядке возрастания. Ввод  данных  сопровождать  соответствующими  запросами,  а вывод -наименованиями выводимых переменных.

# %% [markdown]
# #### Задание 2.
#
# Дана непустая последовательность символов. Составить программу, в  которой  требуется  построить  и  напечатать  множество,  элементами  которого являются  встречающиеся  в  последовательности  (согласно  полученному  варианту задания).
#
# ![image-2.png](attachment:image-2.png)
