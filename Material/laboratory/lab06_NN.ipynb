# %% [markdown]
# ## <center>Лабораторная работа №6</center>
#
# **Тема:** Разработка, отладка и испытание алгоритмов и программ работы с многомерными списками.
#
# **Цель:** Получить навыки разработки, отладки и испытаний программ, использующих двумерные списки.
#
# **Материал:** [Лекция 2.1 Списки, кортежи и множества](../../material/lectures/lect02_01.ipynb)
#
#
# ### <center>Задание</center>

# %% [markdown]
# **Получены значения температуры воздуха за 4 дня с трех метеостанций, расположенных в разных регионах:**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **1. Распечатать температуру на 2-й метеостанции за 4-й день и на 3-й метеостанции за 1-й день.**

# %% [markdown]
# **2. Распечатать показания термометров всех метеостанций за 2-й день.**

# %% [markdown]
# **3. Определить среднюю температуру на 3-й метеостанции.**

# %% [markdown]
# **4. Распечатать, в какие дни и на каких метеостанциях температура была в диапазоне 24-26 градусов тепла.**
