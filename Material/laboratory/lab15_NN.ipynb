# %% [markdown]
# ## <center>Лабораторная работа №15</center>
#
# **Тема:** Разработка, отладка и испытание программ с применением декораторов классов
#
# **Цель:** Получить навыки разработки, отладки и испытаний программ, использующих встроенные декораторы.
#
# **Материал:** [Лекция 3.4  Свойства и декораторы классов](../../material/lectures/lect03_04.ipynb)

# %% [markdown]
# #### <center>Пример использования декоратора измерения времени @timeit</center>
#
# Этот декоратор измеряет время выполнения функции, которую декорирует.

# %%
import time
from functools import wraps

def timeit(method):
    @wraps(method)
    def timed(*args, **kw):
        ts = time.monotonic()
        result = method(*args, **kw)
        te = time.monotonic()
        ms = (te - ts) * 1000
        all_args = ', '.join(tuple(f'{a!r}' for a in args)
                             + tuple(f'{k}={v!r}' for k, v in kw.items()))
        print(f'{method.__name__}({all_args}): {ms:2.2f} ms')
        return result
    return timed


# использование:

@timeit
def slow_func(x, y, sleep):
    time.sleep(sleep)
    return x + y

slow_func(10, 20, sleep=2)

# %% [markdown]
# Как видите, нам не нужно вмешиваться в код функции, не нужно каждый раз писать измеритель времени, декоратор экономит нашу работу: надо измерить время – дописали @timeit и видим результат.
#
# **Задание 1 (общее):** В комментариях опишите, что делает функция slow_func.

# %% [markdown]
# **<center>Индивидуальные задания:</center>**
#
# **Создайте функцию, которая выполняет сортировку списка из некоторого количества элементов (все элементы целые, заданы случайным образом) указанным способом. Проверьте время выполнения функции (см. пример) для 10, 100, 1000, 10000 и 100000 элементов. Данные занесите в таблицу, сделайте вывод.**
#
# Примечание 1. Вместо функции slow_func напишите свою функцию сортировки согласно варианта. Не используйте sleep в своей функции!
#
# Примечание 2. Для внесения изменений в таблицу выполните двойной клик левой клавиши мыши по ней и внесите данные в последний столбец. Например: |1|10|0.02|. После внесения изменений нажмите Run (Выполнить).
#
# | № | Кол-во элементов | Время выполнения |
# | --- | --- | --- |
# |1|10||
# |2|100||
# |3|1000||
# |4|10000||
# |5|100000||

# %% [markdown]
# **Вариант** 1, 7, 13, 19, 25
#
# Сортировка списка методом вставки по возрастанию.
#
# **Вариант** 2, 8, 14, 20,
#
# Сортировка списка методом вставки по убыванию.
#
# **Вариант** 3, 9, 15, 21, 27
#
# Сортировка списка методом обмена по возрастанию.
#
# **Вариант** 4, 10, 16, 22, 28
#
# Сортировка списка методом обмена по убыванию.
#
# **Вариант** 5, 11, 17, 23
#
# Сортиртировка списка методом пузырька по возрастанию.
#
# **Вариант** 6, 12, 18, 24
#
# Сортировка списка методом пузырька по убыванию.
