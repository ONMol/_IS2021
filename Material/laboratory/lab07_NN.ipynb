# %% [markdown]
# ## <center>Лабораторная работа №7</center>
#
# **Тема:** Разработка, отладка и испытание алгоритмов и программ с использованием кортежей и словарей.
#
# **Цель:** Получить навыки разработки, отладки и испытаний программ, использующих кортежи и словари.
#
# **Материал:** [Лекция 2.1 Списки, кортежи и множества](../../material/lectures/lect02_01.ipynb)
#
#
# #### <center>Индивидуальные задания</center>

# %% [markdown]
# ### <u>Задание 1</u>
# **Упакуйте в кортеж:**
#
#  1. Список дней недели.
#
#  2. Список из семи любых фамилий студентов, присутствующих в аудитории.
#
#  3. Список из семи любых названий месяцев.
#
#  4. Список из семи любых имен студентов, присутствующих в аудитории.
#
#  5. Список из семи любых названий предметов в расписании.
#
#  6. Список из семи любых предметов в вашем рюкзаке.
#
#  7. Список из семи любых улиц города.
#
#  8. Список из семи любых городов.
#
#  9. Список из семи любых марок автомобилей.
#
#  10. Список из семи любых деталей компьютера.
#
#  11. Список из семи любых фильмов.
#
#  12. Список из семи любых стран.
#
#  13. Список из семи любых приложений Windows.
#
#  14. Список из семи любых математических функций Python.
#
#  15. Список из семи любых языков программирования.

# %%
users = ("Tom", "Bob", "Sam", "Kate")

# %% [markdown]
# Создайте из первых трех элементов кортежа новый кортеж new_tu.

# %%
users = ("Tom", "Bob", "Sam", "Kate")
new_tu = users[0:3]
print(new_tu)
# Out:
# ('Tom', 'Bob', 'Sam')

# %% [markdown]
# Создайте из четырех оставшихся элементов кортежа кортеж new_tu2. Создайте кортеж all_tu, который содержал бы все кортежи включая исходный.

# %% [markdown]
# ### <u>Задание 2</u>
# **Создайте словарь в котором хранятся семь пар ключ-значение следующего типа:**
# 1. Фамилии учащихся и их средний балл.
#
# 2. Марки автомобилей и их скорость.
#
# 3. Фамили пользователей и их пароли.
#
# 4. Фильмы и их рейтинг.
#
# 5. Цвета радуги и их английский эквивалент.
#
# 6. Дисциплины и преподаватели..
#
# 7. Дата заметки и ее содержание.
#
# 8. Файл файловой системы и его размер.
#
# 9. Файл файловой системы и путь к нему.
#
# 10. Звуковой файл и его жанр.
#
# 11. Страна и ее столица.
#
# 12. Страна и ее население.
#
# 13. Страна и ее площадь.
#
# 14. Продукт и его цена.
#
# 15. Художник и его год рождения.

# %% [markdown]
# **Построчно распечатайте пары ключ-значение.**

# %% [markdown]
# **Найдите значение по введенному с клавиатуры ключу.**
